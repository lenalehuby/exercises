# %% [markdown]
# #  Synthetic Data Generation and Training Workflow with Warehouse Sim Ready Assets
#
# This notebook is the second part of the SDG and Training Workflow. Here we trainin an Object Detection Network with TAO toolkit
#
# A high level overview of the steps:
# * Pulling TAO Docker Container
# * Training Detectnet_v2 model with generated Synthetic Data
# * Visualizing Model Performance on Sample Real World Data

# %% [markdown]
# #### Run the `generate_data.sh` script. Ensure the path to Isaac Sim is set correctly in the script (`ISAAC_SIM_PATH` corresponds to where Isaac Sim is installed locally on your workstation)

# %% [markdown]
# ### Table of Contents
#
# This notebook shows an example usecase of Object Detection using DetectNet_v2 in the Train Adapt Optimize (TAO) Toolkit. The model will be trained with the Synthetic Data generated previously.
#
# 1. [Set up TAO via Docker container](#head-1)
# 2. [Download Pretrained model](#head-2)
# 3. [Convert Dataset to TFRecords for TAO](#head-3)
# 4. [Provide training specification](#head-4)
# 5. [Run TAO training](#head-5)
# 6. [Evaluate trained model](#head-6)
# 7. [Visualize Model Predictions on Real World Data](#head-7)
# 8. [Next Steps](#head-8)

# %% [markdown]
# ## 1. Set up TAO via Docker Container <a class="anchor" id="head-1"></a>
#
# * We will follow the pre-requisites section of [instructions](https://docs.nvidia.com/tao/tao-toolkit/text/tao_toolkit_quick_start_guide.html#running-tao-toolkit) for using TAO toolkit. Make sure that the pre-requisite steps are completed (installing `docker`, `nvidia container toolkit` and `docker login nvcr.io`)
#
# * The docker container being used for training will be pulled in the cells below, make sure you have completed the pre-requisite steps and `docker login nvcr.io` to allow pulling of the container from NGC

# %%
import os
# %env DOCKER_REGISTRY=nvcr.io
# %env DOCKER_NAME=nvidia/tao/tao-toolkit
# %env DOCKER_TAG=4.0.0-tf1.15.5 ## for TensorFlow docker

# %env DOCKER_CONTAINER=nvcr.io/nvidia/tao/tao-toolkit:4.0.0-tf1.15.5
# Out:
# env: DOCKER_REGISTRY=nvcr.io
# env: DOCKER_NAME=nvidia/tao/tao-toolkit
# env: DOCKER_TAG=4.0.0-tf1.15.5 ## for TensorFlow docker
# env: DOCKER_CONTAINER=nvcr.io/nvidia/tao/tao-toolkit:4.0.0-tf1.15.5

# %% [markdown]
# ## 2. Download Pretrained Model <a class="anchor" id="head-2"></a>
#
# * We will use the `detectnet_v2` Object Detection model with a `resnet18` backbone
# * Make sure the `LOCAL_PROJECT_DIR` environment variable has the path of this cloned repository in the cell below

# %%
# os.environ["LOCAL_PROJECT_DIR"] = "<LOCAL_PATH_OF_CLONED_REPO>"
os.environ["LOCAL_PROJECT_DIR"] = os.path.dirname(os.getcwd()) # This is the location of the root of the cloned repo
print(os.environ["LOCAL_PROJECT_DIR"])
# Out:
# e:\synthetic_data_generation_training_workflow

# %% [markdown]
# Next, you can use PowerShell to download the model. First, create the folder.
# New-Item -ItemType Directory -Path "E:\synthetic_data_generation_training_workflow\local\training\tao\pretrained_model"
# Invoke-WebRequest -Uri "https://api.ngc.nvidia.com/v2/models/nvidia/tao/pretrained_detectnet_v2/versions/resnet18/files/resnet18.hdf5" -OutFile "E:\synthetic_data_generation_training_workflow\local\training\tao\pretrained_model\resnet18.hdf5"

# %% [markdown]
# ## 3. Convert Dataset to TFRecords for TAO <a class="anchor" id="head-3"></a>
#
# * The `Detectnet_v2` model in TAO expects data in the form of TFRecords for training.
# * We can convert the KITTI Format Dataset generated from Part 1 with the `detectnet_v2 dataset_convert` tool provided with TAO toolkit

# %%
LOCAL_PROJECT_DIR = "E:/synthetic_data_generation_training_workflow"
DOCKER_CONTAINER = "nvcr.io/nvidia/tao/tao-toolkit:4.0.0-tf1.15.5"

# %%
# !docker run --rm --gpus all -v E:/synthetic_data_generation_training_workflow:/workspace/tao-experiments nvcr.io/nvidia/tao/tao-toolkit:4.0.0-tf1.15.5 \
  detectnet_v2 dataset_convert \
  -d /workspace/tao-experiments/local/training/tao/specs/tfrecords/distractors_warehouse.txt \
  -o /workspace/tao-experiments/local/training/tao/tfrecords/distractors_warehouse/
# Out:
# ==============================
# === TAO Toolkit TensorFlow ===
# ==============================
#
# NVIDIA Release 4.0.0-TensorFlow (build )
# TAO Toolkit Version 4.0.0
#
# Various files include modifications (c) NVIDIA CORPORATION & AFFILIATES.  All rights reserved.
#
# This container image and its contents are governed by the TAO Toolkit End User License Agreement.
# By pulling and using the container, you accept the terms and conditions of this license:
# https://developer.nvidia.com/tao-toolkit-software-license-agreement
#
# NOTE: The SHMEM allocation limit is set to the default of 64MB.  This may be
#    insufficient for TAO Toolkit.  NVIDIA recommends the use of the following flags:
#    docker run --gpus all --ipc=host --ulimit memlock=-1 --ulimit stack=67108864 ...
#
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# 2025-09-30 14:58:13,553 [INFO] iva.detectnet_v2.dataio.build_converter: Instantiating a kitti converter
# 2025-09-30 14:58:13,556 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Creating output directory /workspace/tao-experiments/local/training/tao/tfrecords/distractors_warehouse
# 2025-09-30 14:58:13,800 [INFO] iva.detectnet_v2.dataio.kitti_converter_lib: Num images in
# Train: 1800	Val: 200
# 2025-09-30 14:58:13,801 [INFO] iva.detectnet_v2.dataio.kitti_converter_lib: Validation data in partition 0. Hence, while choosing the validationset during training choose validation_fold 0.
# 2025-09-30 14:58:13,801 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 0
# 2025-09-30 14:58:14,062 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 1
# 2025-09-30 14:58:14,245 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 2
# 2025-09-30 14:58:14,398 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 3
# 2025-09-30 14:58:14,541 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 4
# 2025-09-30 14:58:14,746 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 5
# 2025-09-30 14:58:14,894 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 6
# 2025-09-30 14:58:15,041 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 7
# 2025-09-30 14:58:15,208 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 8
# 2025-09-30 14:58:15,374 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 9
# 2025-09-30 14:58:15,565 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'palletjack': 608
#
# 2025-09-30 14:58:15,565 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 0
# 2025-09-30 14:58:18,925 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 1
# 2025-09-30 14:58:21,739 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 2
# 2025-09-30 14:58:24,823 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 3
# 2025-09-30 14:58:28,097 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 4
# 2025-09-30 14:58:31,327 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 5
# 2025-09-30 14:58:34,328 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 6
# 2025-09-30 14:58:37,170 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 7
# 2025-09-30 14:58:40,360 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 8
# 2025-09-30 14:58:43,206 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 9
# 2025-09-30 14:58:46,052 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'palletjack': 5369
#
# 2025-09-30 14:58:46,052 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Cumulative object statistics
# 2025-09-30 14:58:46,052 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'palletjack': 5977
#
# 2025-09-30 14:58:46,052 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Class map.
# Label in GT: Label in tfrecords file
# b'palletjack': b'palletjack'
# 2025-09-30 14:58:46,052 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Tfrecords generation complete.
# For the dataset_config in the experiment_spec, please use labels in the tfrecords file, while writing the classmap.
#
# Telemetry data couldn't be sent, but the command ran successfully.
# [WARNING]: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)>
# Execution status: PASS
# 2025-09-30 14:57:45.977250: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
print("Converting Tfrecords for palletjack with additional distractors")

# !mkdir -p E:/synthetic_data_generation_training_workflow/local/training/tao/tfrecords/distractors_additional && rm -rf E:/synthetic_data_generation_training_workflow/local/training/tao/tfrecords/distractors_additional/*

# !docker run --rm --gpus all -v E:/synthetic_data_generation_training_workflow:/workspace/tao-experiments nvcr.io/nvidia/tao/tao-toolkit:4.0.0-tf1.15.5 \
  detectnet_v2 dataset_convert \
  -d /workspace/tao-experiments/local/training/tao/specs/tfrecords/distractors_additional.txt \
  -o /workspace/tao-experiments/local/training/tao/tfrecords/distractors_additional/
# Out:
# Converting Tfrecords for palletjack with additional distractors
# The syntax of the command is incorrect.
# ==============================
# === TAO Toolkit TensorFlow ===
# ==============================
#
# NVIDIA Release 4.0.0-TensorFlow (build )
# TAO Toolkit Version 4.0.0
#
# Various files include modifications (c) NVIDIA CORPORATION & AFFILIATES.  All rights reserved.
#
# This container image and its contents are governed by the TAO Toolkit End User License Agreement.
# By pulling and using the container, you accept the terms and conditions of this license:
# https://developer.nvidia.com/tao-toolkit-software-license-agreement
#
# NOTE: The SHMEM allocation limit is set to the default of 64MB.  This may be
#    insufficient for TAO Toolkit.  NVIDIA recommends the use of the following flags:
#    docker run --gpus all --ipc=host --ulimit memlock=-1 --ulimit stack=67108864 ...
#
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# 2025-09-30 15:02:23,825 [INFO] iva.detectnet_v2.dataio.build_converter: Instantiating a kitti converter
# 2025-09-30 15:02:23,828 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Creating output directory /workspace/tao-experiments/local/training/tao/tfrecords/distractors_additional
# 2025-09-30 15:02:23,844 [INFO] iva.detectnet_v2.dataio.kitti_converter_lib: Num images in
# Train: 1800	Val: 200
# 2025-09-30 15:02:23,844 [INFO] iva.detectnet_v2.dataio.kitti_converter_lib: Validation data in partition 0. Hence, while choosing the validationset during training choose validation_fold 0.
# 2025-09-30 15:02:23,845 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 0
# 2025-09-30 15:02:24,055 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 1
# 2025-09-30 15:02:24,222 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 2
# 2025-09-30 15:02:24,383 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 3
# 2025-09-30 15:02:24,542 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 4
# 2025-09-30 15:02:24,701 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 5
# 2025-09-30 15:02:24,940 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 6
# 2025-09-30 15:02:25,097 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 7
# 2025-09-30 15:02:25,258 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 8
# 2025-09-30 15:02:25,431 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 9
# 2025-09-30 15:02:25,599 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'palletjack': 527
#
# 2025-09-30 15:02:25,599 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 0
# 2025-09-30 15:02:29,313 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 1
# 2025-09-30 15:02:32,324 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 2
# 2025-09-30 15:02:35,518 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 3
# 2025-09-30 15:02:39,574 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 4
# 2025-09-30 15:02:42,180 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 5
# 2025-09-30 15:02:45,093 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 6
# 2025-09-30 15:02:47,758 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 7
# 2025-09-30 15:02:50,773 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 8
# 2025-09-30 15:02:53,467 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 9
# 2025-09-30 15:02:56,129 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'palletjack': 4650
#
# 2025-09-30 15:02:56,129 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Cumulative object statistics
# 2025-09-30 15:02:56,129 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'palletjack': 5177
#
# 2025-09-30 15:02:56,129 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Class map.
# Label in GT: Label in tfrecords file
# b'palletjack': b'palletjack'
# 2025-09-30 15:02:56,130 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Tfrecords generation complete.
# For the dataset_config in the experiment_spec, please use labels in the tfrecords file, while writing the classmap.
#
# Telemetry data couldn't be sent, but the command ran successfully.
# [WARNING]: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)>
# Execution status: PASS
# 2025-09-30 15:01:55.073425: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
print("Converting Tfrecords for kitti trainval dataset")

# !mkdir -p E:/synthetic_data_generation_training_workflow/local/training/tao/tfrecords/no_distractors && rm -rf E:/synthetic_data_generation_training_workflow/local/training/tao/tfrecords/no_distractors/*

# !docker run --rm --gpus all -v E:/synthetic_data_generation_training_workflow:/workspace/tao-experiments nvcr.io/nvidia/tao/tao-toolkit:4.0.0-tf1.15.5 \
  detectnet_v2 dataset_convert \
  -d /workspace/tao-experiments/local/training/tao/specs/tfrecords/no_distractors.txt \
  -o /workspace/tao-experiments/local/training/tao/tfrecords/no_distractors/
# Out:
# Converting Tfrecords for kitti trainval dataset
# The syntax of the command is incorrect.
# ==============================
# === TAO Toolkit TensorFlow ===
# ==============================
#
# NVIDIA Release 4.0.0-TensorFlow (build )
# TAO Toolkit Version 4.0.0
#
# Various files include modifications (c) NVIDIA CORPORATION & AFFILIATES.  All rights reserved.
#
# This container image and its contents are governed by the TAO Toolkit End User License Agreement.
# By pulling and using the container, you accept the terms and conditions of this license:
# https://developer.nvidia.com/tao-toolkit-software-license-agreement
#
# NOTE: The SHMEM allocation limit is set to the default of 64MB.  This may be
#    insufficient for TAO Toolkit.  NVIDIA recommends the use of the following flags:
#    docker run --gpus all --ipc=host --ulimit memlock=-1 --ulimit stack=67108864 ...
#
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# 2025-09-30 15:07:38,938 [INFO] iva.detectnet_v2.dataio.build_converter: Instantiating a kitti converter
# 2025-09-30 15:07:38,940 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Creating output directory /workspace/tao-experiments/local/training/tao/tfrecords/no_distractors
# 2025-09-30 15:07:38,951 [INFO] iva.detectnet_v2.dataio.kitti_converter_lib: Num images in
# Train: 900	Val: 100
# 2025-09-30 15:07:38,951 [INFO] iva.detectnet_v2.dataio.kitti_converter_lib: Validation data in partition 0. Hence, while choosing the validationset during training choose validation_fold 0.
# 2025-09-30 15:07:38,952 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 0
# 2025-09-30 15:07:39,204 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 1
# 2025-09-30 15:07:39,415 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 2
# 2025-09-30 15:07:39,496 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 3
# 2025-09-30 15:07:39,593 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 4
# 2025-09-30 15:07:39,681 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 5
# 2025-09-30 15:07:39,759 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 6
# 2025-09-30 15:07:39,857 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 7
# 2025-09-30 15:07:39,939 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 8
# 2025-09-30 15:07:40,018 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 9
# 2025-09-30 15:07:40,095 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'palletjack': 304
#
# 2025-09-30 15:07:40,095 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 0
# 2025-09-30 15:07:41,794 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 1
# 2025-09-30 15:07:43,202 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 2
# 2025-09-30 15:07:44,453 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 3
# 2025-09-30 15:07:45,625 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 4
# 2025-09-30 15:07:46,771 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 5
# 2025-09-30 15:07:47,988 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 6
# 2025-09-30 15:07:49,653 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 7
# 2025-09-30 15:07:50,814 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 8
# 2025-09-30 15:07:52,020 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 9
# 2025-09-30 15:07:53,130 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'palletjack': 2746
#
# 2025-09-30 15:07:53,130 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Cumulative object statistics
# 2025-09-30 15:07:53,130 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'palletjack': 3050
#
# 2025-09-30 15:07:53,130 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Class map.
# Label in GT: Label in tfrecords file
# b'palletjack': b'palletjack'
# 2025-09-30 15:07:53,130 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Tfrecords generation complete.
# For the dataset_config in the experiment_spec, please use labels in the tfrecords file, while writing the classmap.
#
# Telemetry data couldn't be sent, but the command ran successfully.
# [WARNING]: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)>
# Execution status: PASS
# 2025-09-30 15:07:19.704765: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %% [markdown]
# ## 4. Provide Training Specification File <a class="anchor" id="head-4"></a>
#
# * The spec file for training with TAO is provided under `$LOCAL_PROJECT_DIR/specs/training/resnet18_distractors.txt`
# * The tfrecords and the synthetic data generated in the previous steps are provided under the `dataset_config` parameter of the file
# * Other parameters like `augmentation_config`, `model_config`, `postprocessing_config` can be adjusted. Refer to [this](https://docs.nvidia.com/tao/tao-toolkit/text/object_detection/detectnet_v2.html) for a detailed guideline on adjusting the parameters in the spec file
# * For training our model to detect `palletjacks` this `spec` file provided can be used directly

# %%
with open(r"E:/synthetic_data_generation_training_workflow/local/training/tao/specs/training/resnet18_distractors.txt") as f:
    print(f.read())
# Out:
# random_seed: 42
# dataset_config {
#   data_sources {
#     tfrecords_path: "/workspace/tao-experiments/local/training/tao/tfrecords/distractors_warehouse/*"
#     image_directory_path: "/workspace/tao-experiments/palletjack_sdg/palletjack_data/distractors_warehouse/Camera"
#   }
#
#   data_sources {
#     tfrecords_path: "/workspace/tao-experiments/local/training/tao/tfrecords/distractors_additional/*"
#     image_directory_path: "/workspace/tao-experiments/palletjack_sdg/palletjack_data/distractors_additional/Camera"
#   }
#
#   data_sources {
#     tfrecords_path: "/workspace/tao-experiments/local/training/tao/tfrecords/no_distractors/*"
#     image_directory_path: "/workspace/tao-experiments/palletjack_sdg/palletjack_data/no_distractors/Camera"
#   }
#
#   image_extension: "png"
#
#   target_class_mapping {
#     key: "palletjack"
#     value: "palletjack"
#   }
#
#  validation_fold: 1
#
# }
#
# augmentation_config {
#   preprocessing {
#     output_image_width: 640
#     output_image_height: 352
#     min_bbox_width: 20.0
#     min_bbox_height: 20.0
#     output_image_channel: 3
#   }
#   spatial_augmentation {
#     hflip_probability: 0.5
#     zoom_min: 0.5
#     zoom_max: 1.5
#     translate_max_x: 8.0
#     translate_max_y: 8.0
#   }
#   color_augmentation {
#     hue_rotation_max: 25.0
#     saturation_shift_max: 0.20000000298
#     contrast_scale_max: 0.10000000149
#     contrast_center: 0.5
#   }
# }
#
# postprocessing_config {
#   target_class_config {
#     key: "palletjack"
#     value {
#       clustering_config {
#         clustering_algorithm: DBSCAN
#         dbscan_confidence_threshold: 0.9
#         coverage_threshold: 0.00499999988824
#         dbscan_eps: 0.15000000596
#         dbscan_min_samples: 0.0500000007451
#         minimum_bounding_box_height: 20
#       }
#     }
#   }
# }
#
# model_config {
#   pretrained_model_file: "/workspace/tao-experiments/local/training/tao/pretrained_model/resnet18.hdf5"
#   num_layers: 18
#   use_batch_norm: true
#   load_graph: false
#   all_projections: true
#
#   objective_set {
#     bbox {
#       scale: 35.0
#
#       offset: 0.5
#     }
#     cov {
#     }
#   }
#   arch: "resnet"
# }
#
#
# evaluation_config {
#   validation_period_during_training: 10
#   first_validation_epoch: 5
#   minimum_detection_ground_truth_overlap {
#     key: "palletjack"
#     value: 0.5
#   }
#   evaluation_box_config {
#     key: "palletjack"
#     value {
#       minimum_height: 25
#       maximum_height: 9999
#       minimum_width: 25
#       maximum_width: 9999
#     }
#   }
#   average_precision_mode: INTEGRATE
# }
#
# cost_function_config {
#   target_classes {
#     name: "palletjack"
#     class_weight: 1.0
#     coverage_foreground_weight: 0.0500000007451
#     objectives {
#       name: "cov"
#       initial_weight: 1.0
#       weight_target: 1.0
#     }
#     objectives {
#       name: "bbox"
#       initial_weight: 10.0
#       weight_target: 1.0
#     }
#   }
#   enable_autoweighting: true
#   max_objective_weight: 0.999899983406
#   min_objective_weight: 9.99999974738e-05
# }
#
# training_config {
#   batch_size_per_gpu: 4
#   num_epochs: 100
#   learning_rate {
#     soft_start_annealing_schedule {
#       min_learning_rate: 5e-06
#       max_learning_rate: 5e-04
#       soft_start: 0.10000000149
#       annealing: 0.699999988079
#     }
#   }
#   regularizer {
#     type: L1
#     weight: 3.00000002618e-09
#   }
#   optimizer {
#     adam {
#       epsilon: 9.99999993923e-09
#       beta1: 0.899999976158
#       beta2: 0.999000012875
#     }
#   }
#   cost_scaling {
#     initial_exponent: 20.0
#     increment: 0.005
#     decrement: 1.0
#   }
#   visualizer{
#     enabled: true
#     num_images: 10
#     scalar_logging_frequency: 10
#     infrequent_logging_frequency: 5
#     target_class_config {
#       key: "palletjack"
#       value: {
#         coverage_threshold: 0.005
#       }
#     }
#   }
#   checkpoint_interval: 10
# }
#
# bbox_rasterizer_config {
#   target_class_config {
#     key: "palletjack"
#     value {
#       cov_center_x: 0.5
#       cov_center_y: 0.5
#       cov_radius_x: 1.0
#       cov_radius_y: 1.0
#       bbox_min_radius: 1.0
#     }
#   }
#   deadzone_radius: 0.400000154972
# }

# %% [markdown]
# ### Hyperparameters can be set in the `spec` file. Adjust batch size parameter depending on the VRAM of your GPU
#
# * You can increase the number of epochs, the number of false positives in real world images keeps decreasing (mAP does not change much after ~250 epochs and usually results in the best trained model for the given dataset)

# %% [markdown]
# ## 5. Run TAO Training <a class="anchor" id="head-5"></a>
#
# * The `$LOCAL_PROJECT_DIR` will be mounted to the TAO docker for training, this contains all the data, pretrained model and spec files (training and inference) needed
#
# #### Ensure that no `_warning.json` file exists in the `$LOCAL_PROJECT_DIR/cloud/training/tao/tfrecords` sub-folders (`distractors_additional`, `ditractors_warehouse` and `no_distractors`)
# * Delete the `_warning.json` files before beginning training
# * TAO training won't begin if the structure of the `tfrecords` folder directories is not as expected

# %%
# Setting up env variables for cleaner command line commands.
# %env KEY=nvidia_tlt
# %env NUM_GPUS=1
# Out:
# env: KEY=nvidia_tlt
# env: NUM_GPUS=1

# %% [markdown]
# * TAO Training can be stopped and resumed (`checkpoint_interval` parameter specified in the `spec` file)
# * Tensorboard visualization can be used with TAO [instructions](https://docs.nvidia.com/tao/tao-toolkit/text/tensorboard_visualization.html#visualizing-using-tensorboard).
# * The `$RESULTS_DIR` parameter is the folder where the `$LOCAL_PROJECT_DIR/local/training/tao/detectnet_v2/resnet18_palletjack` folder which is specified with the `-i` flag in the command below

# %%
# %env KEY=nvidia_tlt
# Out:
# env: KEY=nvidia_tlt

# %%
# !docker run --rm --gpus all --ipc=host --ulimit memlock=-1 --ulimit stack=67108864 -v E:/synthetic_data_generation_training_workflow:/workspace/tao-experiments nvcr.io/nvidia/tao/tao-toolkit:4.0.0-tf1.15.5 \
  detectnet_v2 train \
  -e /workspace/tao-experiments/local/training/tao/specs/training/resnet18_distractors.txt \
  -r /workspace/tao-experiments/local/training/tao/detectnet_v2/resnet18_palletjack \
  -k nvidia_tlt
# Out:
# ==============================
# === TAO Toolkit TensorFlow ===
# ==============================
#
# NVIDIA Release 4.0.0-TensorFlow (build )
# TAO Toolkit Version 4.0.0
#
# Various files include modifications (c) NVIDIA CORPORATION & AFFILIATES.  All rights reserved.
#
# This container image and its contents are governed by the TAO Toolkit End User License Agreement.
# By pulling and using the container, you accept the terms and conditions of this license:
# https://developer.nvidia.com/tao-toolkit-software-license-agreement
#
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# 2025-10-01 15:12:12,289 [INFO] iva.common.logging.logging: Log file already exists at /workspace/tao-experiments/local/training/tao/detectnet_v2/resnet18_palletjack/status.json
# 2025-10-01 15:12:12,292 [INFO] root: Starting DetectNet_v2 Training job
# 2025-10-01 15:12:12,293 [INFO] __main__: Loading experiment spec at /workspace/tao-experiments/local/training/tao/specs/training/resnet18_distractors.txt.
# 2025-10-01 15:12:12,295 [INFO] iva.detectnet_v2.spec_handler.spec_loader: Merging specification from /workspace/tao-experiments/local/training/tao/specs/training/resnet18_distractors.txt
# 2025-10-01 15:12:12,306 [INFO] root: Training gridbox model.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:153: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# 2025-10-01 15:12:12,306 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:153: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# 2025-10-01 15:12:13,631 [INFO] root: Sampling mode of the dataloader was set to user_defined.
# 2025-10-01 15:12:13,652 [INFO] root: Building DetectNet V2 model
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# 2025-10-01 15:12:13,652 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# 2025-10-01 15:12:13,653 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# 2025-10-01 15:12:13,669 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/third_party/keras/tensorflow_backend.py:187: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# 2025-10-01 15:12:14,629 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/third_party/keras/tensorflow_backend.py:187: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# 2025-10-01 15:12:15,129 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# 2025-10-01 15:12:15,130 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# 2025-10-01 15:12:15,130 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 2025-10-01 15:12:15,498 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 2025-10-01 15:12:23,808 [INFO] iva.detectnet_v2.objectives.bbox_objective: Default L1 loss function will be used.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 3, 352, 640)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 64, 176, 320) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 64, 176, 320) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 176, 320) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_1 (Conv2D)        (None, 64, 88, 160)  36928       activation_1[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_1 (BatchNormalizati (None, 64, 88, 160)  256         block_1a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1a_relu_1 (Activation)    (None, 64, 88, 160)  0           block_1a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_2 (Conv2D)        (None, 64, 88, 160)  36928       block_1a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_shortcut (Conv2D) (None, 64, 88, 160)  4160        activation_1[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_2 (BatchNormalizati (None, 64, 88, 160)  256         block_1a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_shortcut (BatchNorm (None, 64, 88, 160)  256         block_1a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 88, 160)  0           block_1a_bn_2[0][0]
#                                                                  block_1a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_1a_relu (Activation)      (None, 64, 88, 160)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_1 (Conv2D)        (None, 64, 88, 160)  36928       block_1a_relu[0][0]
# __________________________________________________________________________________________________
# block_1b_bn_1 (BatchNormalizati (None, 64, 88, 160)  256         block_1b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1b_relu_1 (Activation)    (None, 64, 88, 160)  0           block_1b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_2 (Conv2D)        (None, 64, 88, 160)  36928       block_1b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_shortcut (Conv2D) (None, 64, 88, 160)  4160        block_1a_relu[0][0]
# __________________________________________________________________________________________________
# block_1b_bn_2 (BatchNormalizati (None, 64, 88, 160)  256         block_1b_conv_2[0][0]
# __________________________________________________________________________________________________
# block_1b_bn_shortcut (BatchNorm (None, 64, 88, 160)  256         block_1b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 88, 160)  0           block_1b_bn_2[0][0]
#                                                                  block_1b_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_1b_relu (Activation)      (None, 64, 88, 160)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_1 (Conv2D)        (None, 128, 44, 80)  73856       block_1b_relu[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_1 (BatchNormalizati (None, 128, 44, 80)  512         block_2a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2a_relu_1 (Activation)    (None, 128, 44, 80)  0           block_2a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_2 (Conv2D)        (None, 128, 44, 80)  147584      block_2a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_shortcut (Conv2D) (None, 128, 44, 80)  8320        block_1b_relu[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_2 (BatchNormalizati (None, 128, 44, 80)  512         block_2a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_shortcut (BatchNorm (None, 128, 44, 80)  512         block_2a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128, 44, 80)  0           block_2a_bn_2[0][0]
#                                                                  block_2a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2a_relu (Activation)      (None, 128, 44, 80)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_1 (Conv2D)        (None, 128, 44, 80)  147584      block_2a_relu[0][0]
# __________________________________________________________________________________________________
# block_2b_bn_1 (BatchNormalizati (None, 128, 44, 80)  512         block_2b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2b_relu_1 (Activation)    (None, 128, 44, 80)  0           block_2b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_2 (Conv2D)        (None, 128, 44, 80)  147584      block_2b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_shortcut (Conv2D) (None, 128, 44, 80)  16512       block_2a_relu[0][0]
# __________________________________________________________________________________________________
# block_2b_bn_2 (BatchNormalizati (None, 128, 44, 80)  512         block_2b_conv_2[0][0]
# __________________________________________________________________________________________________
# block_2b_bn_shortcut (BatchNorm (None, 128, 44, 80)  512         block_2b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 128, 44, 80)  0           block_2b_bn_2[0][0]
#                                                                  block_2b_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2b_relu (Activation)      (None, 128, 44, 80)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_1 (Conv2D)        (None, 256, 22, 40)  295168      block_2b_relu[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_1 (BatchNormalizati (None, 256, 22, 40)  1024        block_3a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3a_relu_1 (Activation)    (None, 256, 22, 40)  0           block_3a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_2 (Conv2D)        (None, 256, 22, 40)  590080      block_3a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_shortcut (Conv2D) (None, 256, 22, 40)  33024       block_2b_relu[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_2 (BatchNormalizati (None, 256, 22, 40)  1024        block_3a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_shortcut (BatchNorm (None, 256, 22, 40)  1024        block_3a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 256, 22, 40)  0           block_3a_bn_2[0][0]
#                                                                  block_3a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3a_relu (Activation)      (None, 256, 22, 40)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_1 (Conv2D)        (None, 256, 22, 40)  590080      block_3a_relu[0][0]
# __________________________________________________________________________________________________
# block_3b_bn_1 (BatchNormalizati (None, 256, 22, 40)  1024        block_3b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3b_relu_1 (Activation)    (None, 256, 22, 40)  0           block_3b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_2 (Conv2D)        (None, 256, 22, 40)  590080      block_3b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_shortcut (Conv2D) (None, 256, 22, 40)  65792       block_3a_relu[0][0]
# __________________________________________________________________________________________________
# block_3b_bn_2 (BatchNormalizati (None, 256, 22, 40)  1024        block_3b_conv_2[0][0]
# __________________________________________________________________________________________________
# block_3b_bn_shortcut (BatchNorm (None, 256, 22, 40)  1024        block_3b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 256, 22, 40)  0           block_3b_bn_2[0][0]
#                                                                  block_3b_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3b_relu (Activation)      (None, 256, 22, 40)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_1 (Conv2D)        (None, 512, 22, 40)  1180160     block_3b_relu[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_1 (BatchNormalizati (None, 512, 22, 40)  2048        block_4a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4a_relu_1 (Activation)    (None, 512, 22, 40)  0           block_4a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_2 (Conv2D)        (None, 512, 22, 40)  2359808     block_4a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_shortcut (Conv2D) (None, 512, 22, 40)  131584      block_3b_relu[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_2 (BatchNormalizati (None, 512, 22, 40)  2048        block_4a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_shortcut (BatchNorm (None, 512, 22, 40)  2048        block_4a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 512, 22, 40)  0           block_4a_bn_2[0][0]
#                                                                  block_4a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_4a_relu (Activation)      (None, 512, 22, 40)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_1 (Conv2D)        (None, 512, 22, 40)  2359808     block_4a_relu[0][0]
# __________________________________________________________________________________________________
# block_4b_bn_1 (BatchNormalizati (None, 512, 22, 40)  2048        block_4b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4b_relu_1 (Activation)    (None, 512, 22, 40)  0           block_4b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_2 (Conv2D)        (None, 512, 22, 40)  2359808     block_4b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_shortcut (Conv2D) (None, 512, 22, 40)  262656      block_4a_relu[0][0]
# __________________________________________________________________________________________________
# block_4b_bn_2 (BatchNormalizati (None, 512, 22, 40)  2048        block_4b_conv_2[0][0]
# __________________________________________________________________________________________________
# block_4b_bn_shortcut (BatchNorm (None, 512, 22, 40)  2048        block_4b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 512, 22, 40)  0           block_4b_bn_2[0][0]
#                                                                  block_4b_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_4b_relu (Activation)      (None, 512, 22, 40)  0           add_8[0][0]
# __________________________________________________________________________________________________
# output_bbox (Conv2D)            (None, 4, 22, 40)    2052        block_4b_relu[0][0]
# __________________________________________________________________________________________________
# output_cov (Conv2D)             (None, 1, 22, 40)    513         block_4b_relu[0][0]              2025-10-01 15:12:23,832 [INFO] root: DetectNet V2 model built.
# 2025-10-01 15:12:23,832 [INFO] root: Building rasterizer.
# 2025-10-01 15:12:23,833 [INFO] root: Rasterizers built.
# 2025-10-01 15:12:23,846 [INFO] root: Building training graph.
# 2025-10-01 15:12:23,848 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Serial augmentation enabled = False
# 2025-10-01 15:12:23,848 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Pseudo sharding enabled = False
# 2025-10-01 15:12:23,848 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Max Image Dimensions (all sources): [0, 0]
# 2025-10-01 15:12:23,848 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: number of cpus: 16, io threads: 32, compute threads: 16, buffered batches: 4
# 2025-10-01 15:12:23,848 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: total dataset size 500, number of sources: 3, batch size per gpu: 4, steps: 125
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# 2025-10-01 15:12:23,883 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648566d68>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648566d68>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 15:12:23,915 [WARNING] tensorflow: Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648566d68>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648566d68>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 15:12:23,933 [INFO] iva.detectnet_v2.dataloader.default_dataloader: Bounding box coordinates were detected in the input specification! Bboxes will be automatically converted to polygon coordinates.
# 2025-10-01 15:12:24,119 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: shuffle: True - shard 0 of 1
# WARNING:tensorflow:Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648566da0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648566da0>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 15:12:24,136 [WARNING] tensorflow: Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648566da0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648566da0>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 15:12:24,153 [INFO] iva.detectnet_v2.dataloader.default_dataloader: Bounding box coordinates were detected in the input specification! Bboxes will be automatically converted to polygon coordinates.
# 2025-10-01 15:12:24,322 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: shuffle: True - shard 0 of 1
# WARNING:tensorflow:Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648566e80>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648566e80>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 15:12:24,337 [WARNING] tensorflow: Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648566e80>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648566e80>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 15:12:24,356 [INFO] iva.detectnet_v2.dataloader.default_dataloader: Bounding box coordinates were detected in the input specification! Bboxes will be automatically converted to polygon coordinates.
# 2025-10-01 15:12:24,582 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: shuffle: True - shard 0 of 1
# 2025-10-01 15:12:24,587 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: sampling 3 datasets with weights:
# 2025-10-01 15:12:24,587 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: source: 0 weight: 0.400000
# 2025-10-01 15:12:24,587 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: source: 1 weight: 0.400000
# 2025-10-01 15:12:24,587 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: source: 2 weight: 0.200000
# WARNING:tensorflow:Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7d75aee013c8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7d75aee013c8>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 15:12:24,613 [WARNING] tensorflow: Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7d75aee013c8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7d75aee013c8>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 15:12:24,874 [INFO] __main__: Found 500 samples in training set
# 2025-10-01 15:12:24,878 [INFO] root: Rasterizing tensors.
# 2025-10-01 15:12:25,029 [INFO] root: Tensors rasterized.
# 2025-10-01 15:12:27,033 [INFO] root: Training graph built.
# 2025-10-01 15:12:27,033 [INFO] root: Building validation graph.
# 2025-10-01 15:12:27,034 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Serial augmentation enabled = False
# 2025-10-01 15:12:27,034 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Pseudo sharding enabled = False
# 2025-10-01 15:12:27,034 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Max Image Dimensions (all sources): [0, 0]
# 2025-10-01 15:12:27,034 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: number of cpus: 16, io threads: 32, compute threads: 16, buffered batches: 4
# 2025-10-01 15:12:27,034 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: total dataset size 4500, number of sources: 3, batch size per gpu: 4, steps: 1125
# WARNING:tensorflow:Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648566f98>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648566f98>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 15:12:27,046 [WARNING] tensorflow: Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648566f98>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648566f98>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 15:12:27,068 [INFO] iva.detectnet_v2.dataloader.default_dataloader: Bounding box coordinates were detected in the input specification! Bboxes will be automatically converted to polygon coordinates.
# 2025-10-01 15:12:27,244 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: shuffle: False - shard 0 of 1
# WARNING:tensorflow:Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648566f28>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648566f28>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 15:12:27,257 [WARNING] tensorflow: Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648566f28>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648566f28>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 15:12:27,293 [INFO] iva.detectnet_v2.dataloader.default_dataloader: Bounding box coordinates were detected in the input specification! Bboxes will be automatically converted to polygon coordinates.
# 2025-10-01 15:12:27,467 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: shuffle: False - shard 0 of 1
# WARNING:tensorflow:Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648581048>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648581048>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 15:12:27,480 [WARNING] tensorflow: Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648581048>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7d7648581048>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 15:12:27,497 [INFO] iva.detectnet_v2.dataloader.default_dataloader: Bounding box coordinates were detected in the input specification! Bboxes will be automatically converted to polygon coordinates.
# 2025-10-01 15:12:27,673 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: shuffle: False - shard 0 of 1
# 2025-10-01 15:12:27,677 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: sampling 3 datasets with weights:
# 2025-10-01 15:12:27,677 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: source: 0 weight: 0.400000
# 2025-10-01 15:12:27,677 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: source: 1 weight: 0.400000
# 2025-10-01 15:12:27,677 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: source: 2 weight: 0.200000
# WARNING:tensorflow:Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7d75749694e0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7d75749694e0>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 15:12:27,698 [WARNING] tensorflow: Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7d75749694e0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7d75749694e0>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 15:12:27,867 [INFO] __main__: Found 4500 samples in validation set
# 2025-10-01 15:12:27,867 [INFO] root: Rasterizing tensors.
# 2025-10-01 15:12:28,018 [INFO] root: Tensors rasterized.
# 2025-10-01 15:12:28,253 [INFO] root: Validation graph built.
# 2025-10-01 15:12:29,936 [INFO] root: Running training loop.
# 2025-10-01 15:12:29,937 [INFO] __main__: Checkpoint interval: 10
# 2025-10-01 15:12:29,937 [INFO] __main__: Scalars logged at every 12 steps
# 2025-10-01 15:12:29,937 [INFO] __main__: Images logged at every 625 steps
# INFO:tensorflow:Create CheckpointSaverHook.
# 2025-10-01 15:12:29,940 [INFO] tensorflow: Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# 2025-10-01 15:12:31,954 [INFO] tensorflow: Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# 2025-10-01 15:12:34,046 [INFO] tensorflow: Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 2025-10-01 15:12:35,397 [INFO] tensorflow: Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for step-0.
# 2025-10-01 15:12:43,007 [INFO] tensorflow: Saving checkpoints for step-0.
# INFO:tensorflow:epoch = 0.0, learning_rate = 4.9999994e-06, loss = 0.06013281, step = 0
# 2025-10-01 15:13:23,416 [INFO] tensorflow: epoch = 0.0, learning_rate = 4.9999994e-06, loss = 0.06013281, step = 0
# 2025-10-01 15:13:23,422 [INFO] root: None
# 2025-10-01 15:13:23,439 [INFO] iva.detectnet_v2.tfhooks.task_progress_monitor_hook: Epoch 0/100: loss: 0.06013 learning rate: 0.00000 Time taken: 0:00:00 ETA: 0:00:00
# 2025-10-01 15:13:23,440 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 0.463
# INFO:tensorflow:global_step/sec: 2.41312
# 2025-10-01 15:13:28,391 [INFO] tensorflow: global_step/sec: 2.41312
# INFO:tensorflow:epoch = 0.112, learning_rate = 5.2646537e-06, loss = 0.05519341, step = 14 (5.170 sec)
# 2025-10-01 15:13:28,586 [INFO] tensorflow: epoch = 0.112, learning_rate = 5.2646537e-06, loss = 0.05519341, step = 14 (5.170 sec)
# INFO:tensorflow:global_step/sec: 12.0452
# 2025-10-01 15:13:29,387 [INFO] tensorflow: global_step/sec: 12.0452
# 2025-10-01 15:13:29,388 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 6.856
# INFO:tensorflow:global_step/sec: 12.0933
# 2025-10-01 15:13:30,379 [INFO] tensorflow: global_step/sec: 12.0933
# INFO:tensorflow:global_step/sec: 12.2618
# 2025-10-01 15:13:31,358 [INFO] tensorflow: global_step/sec: 12.2618
# 2025-10-01 15:13:31,442 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 48.702
# INFO:tensorflow:global_step/sec: 12.3334
# 2025-10-01 15:13:32,331 [INFO] tensorflow: global_step/sec: 12.3334
# INFO:tensorflow:global_step/sec: 12.1132
# 2025-10-01 15:13:33,321 [INFO] tensorflow: global_step/sec: 12.1132
# 2025-10-01 15:13:33,491 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 48.828
# INFO:tensorflow:epoch = 0.616, learning_rate = 6.6400253e-06, loss = 0.03535134, step = 77 (5.153 sec)
# 2025-10-01 15:13:33,738 [INFO] tensorflow: epoch = 0.616, learning_rate = 6.6400253e-06, loss = 0.03535134, step = 77 (5.153 sec)
# INFO:tensorflow:global_step/sec: 10.193
# 2025-10-01 15:13:34,499 [INFO] tensorflow: global_step/sec: 10.193
# INFO:tensorflow:global_step/sec: 12.2229
# 2025-10-01 15:13:35,480 [INFO] tensorflow: global_step/sec: 12.2229
# 2025-10-01 15:13:35,719 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 44.880
# INFO:tensorflow:global_step/sec: 12.289
# 2025-10-01 15:13:36,457 [INFO] tensorflow: global_step/sec: 12.289
# INFO:tensorflow:global_step/sec: 12.2823
# 2025-10-01 15:13:37,434 [INFO] tensorflow: global_step/sec: 12.2823
# c4082a88fd2f:142:197 [0] NCCL INFO Bootstrap : Using eth0:172.17.0.2<0>
# c4082a88fd2f:142:197 [0] NCCL INFO NET/Plugin: Failed to find ncclNetPlugin_v6 symbol.
# c4082a88fd2f:142:197 [0] NCCL INFO NET/Plugin: Loaded net plugin NCCL RDMA Plugin (v5)
# c4082a88fd2f:142:197 [0] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v6 symbol.
# c4082a88fd2f:142:197 [0] NCCL INFO NET/Plugin: Loaded coll plugin SHARP (v5)
# c4082a88fd2f:142:197 [0] NCCL INFO cudaDriverVersion 12090
# NCCL version 2.15.1+cuda11.8
# 2025-10-01 15:13:38,829 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 32.160
# INFO:tensorflow:epoch = 1.0, learning_rate = 7.924464e-06, loss = 0.0064660152, step = 125 (5.177 sec)
# 2025-10-01 15:13:38,915 [INFO] tensorflow: epoch = 1.0, learning_rate = 7.924464e-06, loss = 0.0064660152, step = 125 (5.177 sec)
# 2025-10-01 15:13:38,915 [INFO] root: None
# 2025-10-01 15:13:38,916 [INFO] iva.detectnet_v2.tfhooks.task_progress_monitor_hook: Epoch 1/100: loss: 0.00647 learning rate: 0.00001 Time taken: 0:00:24.026344 ETA: 0:39:38.608038
# INFO:tensorflow:global_step/sec: 5.79946
# 2025-10-01 15:13:39,503 [INFO] tensorflow: global_step/sec: 5.79946
# INFO:tensorflow:global_step/sec: 11.7691
# 2025-10-01 15:13:40,523 [INFO] tensorflow: global_step/sec: 11.7691
# 2025-10-01 15:13:40,932 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 47.582
# INFO:tensorflow:global_step/sec: 11.9812
# 2025-10-01 15:13:41,524 [INFO] tensorflow: global_step/sec: 11.9812
# INFO:tensorflow:global_step/sec: 12.1479
# 2025-10-01 15:13:42,512 [INFO] tensorflow: global_step/sec: 12.1479
# 2025-10-01 15:13:43,006 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 48.217
# INFO:tensorflow:global_step/sec: 12.1578
# 2025-10-01 15:13:43,499 [INFO] tensorflow: global_step/sec: 12.1578
# INFO:tensorflow:epoch = 1.496, learning_rate = 9.957948e-06, loss = 0.004882155, step = 187 (5.155 sec)
# 2025-10-01 15:13:44,070 [INFO] tensorflow: epoch = 1.496, learning_rate = 9.957948e-06, loss = 0.004882155, step = 187 (5.155 sec)
# INFO:tensorflow:global_step/sec: 12.3016
# 2025-10-01 15:13:44,475 [INFO] tensorflow: global_step/sec: 12.3016
# 2025-10-01 15:13:45,048 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 48.991
# ...
# 2025-10-01 17:18:03,367 [INFO] iva.detectnet_v2.evaluation.evaluation: step 420 / 1125, 0.10s/step
# 2025-10-01 17:18:04,155 [INFO] iva.detectnet_v2.evaluation.evaluation: step 430 / 1125, 0.08s/step
# 2025-10-01 17:18:05,102 [INFO] iva.detectnet_v2.evaluation.evaluation: step 440 / 1125, 0.09s/step
# 2025-10-01 17:18:05,860 [INFO] iva.detectnet_v2.evaluation.evaluation: step 450 / 1125, 0.08s/step
# 2025-10-01 17:18:06,704 [INFO] iva.detectnet_v2.evaluation.evaluation: step 460 / 1125, 0.08s/step
# 2025-10-01 17:18:07,631 [INFO] iva.detectnet_v2.evaluation.evaluation: step 470 / 1125, 0.09s/step
# 2025-10-01 17:18:08,554 [INFO] iva.detectnet_v2.evaluation.evaluation: step 480 / 1125, 0.09s/step
# 2025-10-01 17:18:09,533 [INFO] iva.detectnet_v2.evaluation.evaluation: step 490 / 1125, 0.10s/step
# 2025-10-01 17:18:10,280 [INFO] iva.detectnet_v2.evaluation.evaluation: step 500 / 1125, 0.07s/step
# 2025-10-01 17:18:11,305 [INFO] iva.detectnet_v2.evaluation.evaluation: step 510 / 1125, 0.10s/step
# 2025-10-01 17:18:12,176 [INFO] iva.detectnet_v2.evaluation.evaluation: step 520 / 1125, 0.09s/step
# 2025-10-01 17:18:13,111 [INFO] iva.detectnet_v2.evaluation.evaluation: step 530 / 1125, 0.09s/step
# 2025-10-01 17:18:13,848 [INFO] iva.detectnet_v2.evaluation.evaluation: step 540 / 1125, 0.07s/step
# 2025-10-01 17:18:14,711 [INFO] iva.detectnet_v2.evaluation.evaluation: step 550 / 1125, 0.09s/step
# 2025-10-01 17:18:15,698 [INFO] iva.detectnet_v2.evaluation.evaluation: step 560 / 1125, 0.10s/step
# 2025-10-01 17:18:16,590 [INFO] iva.detectnet_v2.evaluation.evaluation: step 570 / 1125, 0.09s/step
# 2025-10-01 17:18:17,328 [INFO] iva.detectnet_v2.evaluation.evaluation: step 580 / 1125, 0.07s/step
# 2025-10-01 17:18:18,285 [INFO] iva.detectnet_v2.evaluation.evaluation: step 590 / 1125, 0.10s/step
# 2025-10-01 17:18:19,195 [INFO] iva.detectnet_v2.evaluation.evaluation: step 600 / 1125, 0.09s/step
# 2025-10-01 17:18:19,858 [INFO] iva.detectnet_v2.evaluation.evaluation: step 610 / 1125, 0.07s/step
# 2025-10-01 17:18:20,895 [INFO] iva.detectnet_v2.evaluation.evaluation: step 620 / 1125, 0.10s/step
# 2025-10-01 17:18:21,995 [INFO] iva.detectnet_v2.evaluation.evaluation: step 630 / 1125, 0.11s/step
# 2025-10-01 17:18:23,027 [INFO] iva.detectnet_v2.evaluation.evaluation: step 640 / 1125, 0.10s/step
# 2025-10-01 17:18:23,820 [INFO] iva.detectnet_v2.evaluation.evaluation: step 650 / 1125, 0.08s/step
# 2025-10-01 17:18:24,713 [INFO] iva.detectnet_v2.evaluation.evaluation: step 660 / 1125, 0.09s/step
# 2025-10-01 17:18:25,637 [INFO] iva.detectnet_v2.evaluation.evaluation: step 670 / 1125, 0.09s/step
# 2025-10-01 17:18:26,422 [INFO] iva.detectnet_v2.evaluation.evaluation: step 680 / 1125, 0.08s/step
# 2025-10-01 17:18:27,279 [INFO] iva.detectnet_v2.evaluation.evaluation: step 690 / 1125, 0.09s/step
# 2025-10-01 17:18:28,169 [INFO] iva.detectnet_v2.evaluation.evaluation: step 700 / 1125, 0.09s/step
# 2025-10-01 17:18:28,904 [INFO] iva.detectnet_v2.evaluation.evaluation: step 710 / 1125, 0.07s/step
# 2025-10-01 17:18:29,911 [INFO] iva.detectnet_v2.evaluation.evaluation: step 720 / 1125, 0.10s/step
# 2025-10-01 17:18:30,735 [INFO] iva.detectnet_v2.evaluation.evaluation: step 730 / 1125, 0.08s/step
# 2025-10-01 17:18:31,635 [INFO] iva.detectnet_v2.evaluation.evaluation: step 740 / 1125, 0.09s/step
# 2025-10-01 17:18:32,466 [INFO] iva.detectnet_v2.evaluation.evaluation: step 750 / 1125, 0.08s/step
# 2025-10-01 17:18:33,477 [INFO] iva.detectnet_v2.evaluation.evaluation: step 760 / 1125, 0.10s/step
# 2025-10-01 17:18:34,370 [INFO] iva.detectnet_v2.evaluation.evaluation: step 770 / 1125, 0.09s/step
# 2025-10-01 17:18:35,209 [INFO] iva.detectnet_v2.evaluation.evaluation: step 780 / 1125, 0.08s/step
# 2025-10-01 17:18:35,964 [INFO] iva.detectnet_v2.evaluation.evaluation: step 790 / 1125, 0.08s/step
# 2025-10-01 17:18:36,681 [INFO] iva.detectnet_v2.evaluation.evaluation: step 800 / 1125, 0.07s/step
# 2025-10-01 17:18:37,496 [INFO] iva.detectnet_v2.evaluation.evaluation: step 810 / 1125, 0.08s/step
# 2025-10-01 17:18:38,323 [INFO] iva.detectnet_v2.evaluation.evaluation: step 820 / 1125, 0.08s/step
# 2025-10-01 17:18:39,330 [INFO] iva.detectnet_v2.evaluation.evaluation: step 830 / 1125, 0.10s/step
# 2025-10-01 17:18:40,353 [INFO] iva.detectnet_v2.evaluation.evaluation: step 840 / 1125, 0.10s/step
# 2025-10-01 17:18:41,263 [INFO] iva.detectnet_v2.evaluation.evaluation: step 850 / 1125, 0.09s/step
# 2025-10-01 17:18:42,117 [INFO] iva.detectnet_v2.evaluation.evaluation: step 860 / 1125, 0.09s/step
# 2025-10-01 17:18:42,889 [INFO] iva.detectnet_v2.evaluation.evaluation: step 870 / 1125, 0.08s/step
# 2025-10-01 17:18:44,068 [INFO] iva.detectnet_v2.evaluation.evaluation: step 880 / 1125, 0.12s/step
# 2025-10-01 17:18:44,745 [INFO] iva.detectnet_v2.evaluation.evaluation: step 890 / 1125, 0.07s/step
# 2025-10-01 17:18:45,677 [INFO] iva.detectnet_v2.evaluation.evaluation: step 900 / 1125, 0.09s/step
# 2025-10-01 17:18:46,485 [INFO] iva.detectnet_v2.evaluation.evaluation: step 910 / 1125, 0.08s/step
# 2025-10-01 17:18:47,213 [INFO] iva.detectnet_v2.evaluation.evaluation: step 920 / 1125, 0.07s/step
# 2025-10-01 17:18:47,945 [INFO] iva.detectnet_v2.evaluation.evaluation: step 930 / 1125, 0.07s/step
# 2025-10-01 17:18:48,796 [INFO] iva.detectnet_v2.evaluation.evaluation: step 940 / 1125, 0.09s/step
# 2025-10-01 17:18:49,687 [INFO] iva.detectnet_v2.evaluation.evaluation: step 950 / 1125, 0.09s/step
# 2025-10-01 17:18:50,779 [INFO] iva.detectnet_v2.evaluation.evaluation: step 960 / 1125, 0.11s/step
# 2025-10-01 17:18:51,704 [INFO] iva.detectnet_v2.evaluation.evaluation: step 970 / 1125, 0.09s/step
# 2025-10-01 17:18:52,421 [INFO] iva.detectnet_v2.evaluation.evaluation: step 980 / 1125, 0.07s/step
# 2025-10-01 17:18:53,349 [INFO] iva.detectnet_v2.evaluation.evaluation: step 990 / 1125, 0.09s/step
# 2025-10-01 17:18:54,253 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1000 / 1125, 0.09s/step
# 2025-10-01 17:18:55,055 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1010 / 1125, 0.08s/step
# 2025-10-01 17:18:55,805 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1020 / 1125, 0.08s/step
# 2025-10-01 17:18:56,801 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1030 / 1125, 0.10s/step
# 2025-10-01 17:18:57,612 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1040 / 1125, 0.08s/step
# 2025-10-01 17:18:58,595 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1050 / 1125, 0.10s/step
# 2025-10-01 17:18:59,363 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1060 / 1125, 0.08s/step
# 2025-10-01 17:19:00,353 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1070 / 1125, 0.10s/step
# 2025-10-01 17:19:01,247 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1080 / 1125, 0.09s/step
# 2025-10-01 17:19:01,827 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1090 / 1125, 0.06s/step
# 2025-10-01 17:19:02,369 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1100 / 1125, 0.05s/step
# 2025-10-01 17:19:02,898 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1110 / 1125, 0.05s/step
# 2025-10-01 17:19:03,466 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1120 / 1125, 0.06s/step
#
#   0%|          | 0/50175 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 1/1.:   0%|          | 0/50175 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 1/1.:   3%|▎         | 1683/50175 [00:00<00:02, 16825.20it/s]
# Matching predictions to ground truth, class 1/1.:   7%|▋         | 3480/50175 [00:00<00:02, 17393.67it/s]
# Matching predictions to ground truth, class 1/1.:  10%|█         | 5231/50175 [00:00<00:02, 17430.05it/s]
# Matching predictions to ground truth, class 1/1.:  14%|█▍        | 7059/50175 [00:00<00:02, 17641.65it/s]
# Matching predictions to ground truth, class 1/1.:  18%|█▊        | 8799/50175 [00:00<00:02, 17592.76it/s]
# Matching predictions to ground truth, class 1/1.:  21%|██        | 10564/50175 [00:00<00:02, 17601.17it/s]
# Matching predictions to ground truth, class 1/1.:  25%|██▍       | 12458/50175 [00:00<00:02, 17791.86it/s]
# Matching predictions to ground truth, class 1/1.:  28%|██▊       | 14117/50175 [00:00<00:02, 17048.84it/s]
# Matching predictions to ground truth, class 1/1.:  32%|███▏      | 15887/50175 [00:00<00:02, 17118.84it/s]
# Matching predictions to ground truth, class 1/1.:  35%|███▌      | 17802/50175 [00:01<00:01, 17316.23it/s]
# Matching predictions to ground truth, class 1/1.:  39%|███▉      | 19684/50175 [00:01<00:01, 17449.42it/s]
# Matching predictions to ground truth, class 1/1.:  43%|████▎     | 21611/50175 [00:01<00:01, 17597.49it/s]
# Matching predictions to ground truth, class 1/1.:  47%|████▋     | 23475/50175 [00:01<00:01, 17675.68it/s]
# Matching predictions to ground truth, class 1/1.:  50%|█████     | 25318/50175 [00:01<00:01, 17728.16it/s]
# Matching predictions to ground truth, class 1/1.:  54%|█████▍    | 27168/50175 [00:01<00:01, 17778.14it/s]
# Matching predictions to ground truth, class 1/1.:  58%|█████▊    | 29005/50175 [00:01<00:01, 17734.44it/s]
# Matching predictions to ground truth, class 1/1.:  61%|██████▏   | 30844/50175 [00:01<00:01, 17772.23it/s]
# Matching predictions to ground truth, class 1/1.:  65%|██████▌   | 32667/50175 [00:01<00:00, 17796.89it/s]
# Matching predictions to ground truth, class 1/1.:  69%|██████▉   | 34514/50175 [00:01<00:00, 17831.48it/s]
# Matching predictions to ground truth, class 1/1.:  73%|███████▎  | 36459/50175 [00:02<00:00, 17910.62it/s]
# Matching predictions to ground truth, class 1/1.:  77%|███████▋  | 38390/50175 [00:02<00:00, 17975.87it/s]
# Matching predictions to ground truth, class 1/1.:  80%|████████  | 40287/50175 [00:02<00:00, 18020.27it/s]
# Matching predictions to ground truth, class 1/1.:  84%|████████▍ | 42186/50175 [00:02<00:00, 18061.46it/s]
# Matching predictions to ground truth, class 1/1.:  88%|████████▊ | 44102/50175 [00:02<00:00, 18106.39it/s]
# Matching predictions to ground truth, class 1/1.:  92%|█████████▏| 46000/50175 [00:02<00:00, 18073.06it/s]
# Matching predictions to ground truth, class 1/1.:  95%|█████████▌| 47849/50175 [00:02<00:00, 18076.82it/s]
# Matching predictions to ground truth, class 1/1.:  99%|█████████▉| 49749/50175 [00:02<00:00, 18110.38it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 50175/50175 [00:02<00:00, 18113.71it/s]2025-10-01 17:19:07,605 [INFO] root: Evaluation metrics generated.
#
# Epoch 100/100
# =========================
#
# Validation cost: 0.001341
# Mean average_precision (in %): 35.9478
#
# class name      average precision (in %)
# ------------  --------------------------
# palletjack                       35.9478
#
# Median Inference Time: 0.011717
# 2025-10-01 17:19:07,606 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 0.807
# 2025-10-01 17:19:07,607 [INFO] root: Training loop completed.
# 2025-10-01 17:19:07,608 [INFO] root: Saving trained model.
# 2025-10-01 17:19:11,105 [INFO] root: Model saved.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# 2025-10-01 17:19:11,106 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# 2025-10-01 17:19:11,106 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# 2025-10-01 17:19:11,109 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 0.807
# 2025-10-01 17:19:11,357 [INFO] root: Training op complete.
# 2025-10-01 17:19:11,359 [INFO] root: DetectNet_v2 training job complete.
# Time taken to run __main__:main: 2:06:59.621213.
# c4082a88fd2f:142:197 [0] NCCL INFO Plugin Path : /opt/hpcx/nccl_rdma_sharp_plugin/lib/libnccl-net.so
# c4082a88fd2f:142:197 [0] NCCL INFO P2P plugin IBext
# c4082a88fd2f:142:197 [0] NCCL INFO NET/IB : No device found.
# c4082a88fd2f:142:197 [0] NCCL INFO NET/IB : No device found.
# c4082a88fd2f:142:197 [0] NCCL INFO NET/Socket : Using [0]eth0:172.17.0.2<0>
# c4082a88fd2f:142:197 [0] NCCL INFO Using network Socket
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 00/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 01/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 02/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 03/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 04/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 05/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 06/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 07/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 08/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 09/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 10/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 11/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 12/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 13/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 14/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 15/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 16/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 17/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 18/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 19/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 20/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 21/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 22/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 23/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 24/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 25/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 26/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 27/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 28/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 29/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 30/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Channel 31/32 :    0
# c4082a88fd2f:142:197 [0] NCCL INFO Trees [0] -1/-1/-1->0->-1 [1] -1/-1/-1->0->-1 [2] -1/-1/-1->0->-1 [3] -1/-1/-1->0->-1 [4] -1/-1/-1->0->-1 [5] -1/-1/-1->0->-1 [6] -1/-1/-1->0->-1 [7] -1/-1/-1->0->-1 [8] -1/-1/-1->0->-1 [9] -1/-1/-1->0->-1 [10] -1/-1/-1->0->-1 [11] -1/-1/-1->0->-1 [12] -1/-1/-1->0->-1 [13] -1/-1/-1->0->-1 [14] -1/-1/-1->0->-1 [15] -1/-1/-1->0->-1 [16] -1/-1/-1->0->-1 [17] -1/-1/-1->0->-1 [18] -1/-1/-1->0->-1 [19] -1/-1/-1->0->-1 [20] -1/-1/-1->0->-1 [21] -1/-1/-1->0->-1 [22] -1/-1/-1->0->-1 [23] -1/-1/-1->0->-1 [24] -1/-1/-1->0->-1 [25] -1/-1/-1->0->-1 [26] -1/-1/-1->0->-1 [27] -1/-1/-1->0->-1 [28] -1/-1/-1->0->-1 [29] -1/-1/-1->0->-1 [30] -1/-1/-1->0->-1 [31] -1/-1/-1->0->-1
# c4082a88fd2f:142:197 [0] NCCL INFO Connected all rings
# c4082a88fd2f:142:197 [0] NCCL INFO Connected all trees
# c4082a88fd2f:142:197 [0] NCCL INFO 32 coll channels, 32 p2p channels, 32 p2p channels per peer
# c4082a88fd2f:142:197 [0] NCCL INFO comm 0x7d716843b650 rank 0 nranks 1 cudaDev 0 busId 2d000 - Init COMPLETE
# c4082a88fd2f:142:197 [0] NCCL INFO comm 0x7d716843b650 rank 0 nranks 1 cudaDev 0 busId 2d000 - Destroy COMPLETE
# Telemetry data couldn't be sent, but the command ran successfully.
# [WARNING]: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)>
# Execution status: PASS
# 2025-10-01 15:12:04.860192: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %% [markdown]
# ## 6. Evaluate Trained Model <a class="anchor" id="head-6"></a>
#
# * While generating the `tfrecords` part of the total data generated was kept as a validation set (14% of total data)
# * We will run our model evaluation on this data to obtain metrics

# %%
# !docker run --rm --gpus all -v E:/synthetic_data_generation_training_workflow:/workspace/tao-experiments nvcr.io/nvidia/tao/tao-toolkit:4.0.0-tf1.15.5 \
  detectnet_v2 evaluate \
  -e /workspace/tao-experiments/local/training/tao/specs/training/resnet18_distractors.txt \
  -m /workspace/tao-experiments/local/training/tao/detectnet_v2/resnet18_palletjack/weights/model.tlt \
  -k nvidia_tlt --gpus 1
# Out:
# ==============================
# === TAO Toolkit TensorFlow ===
# ==============================
#
# NVIDIA Release 4.0.0-TensorFlow (build )
# TAO Toolkit Version 4.0.0
#
# Various files include modifications (c) NVIDIA CORPORATION & AFFILIATES.  All rights reserved.
#
# This container image and its contents are governed by the TAO Toolkit End User License Agreement.
# By pulling and using the container, you accept the terms and conditions of this license:
# https://developer.nvidia.com/tao-toolkit-software-license-agreement
#
# NOTE: The SHMEM allocation limit is set to the default of 64MB.  This may be
#    insufficient for TAO Toolkit.  NVIDIA recommends the use of the following flags:
#    docker run --gpus all --ipc=host --ulimit memlock=-1 --ulimit stack=67108864 ...
#
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# 2025-10-01 17:21:41,987 [INFO] iva.detectnet_v2.spec_handler.spec_loader: Merging specification from /workspace/tao-experiments/local/training/tao/specs/training/resnet18_distractors.txt
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:153: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# 2025-10-01 17:21:42,014 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:153: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# 2025-10-01 17:21:42,538 [INFO] root: Loading model weights.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# 2025-10-01 17:21:45,049 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# 2025-10-01 17:21:45,057 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# 2025-10-01 17:21:45,079 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# 2025-10-01 17:21:45,938 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# 2025-10-01 17:21:45,938 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# 2025-10-01 17:21:45,939 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 2025-10-01 17:21:46,150 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# 2025-10-01 17:21:46,800 [INFO] iva.detectnet_v2.objectives.bbox_objective: Default L1 loss function will be used.
# 2025-10-01 17:21:46,800 [INFO] root: Building dataloader.
# 2025-10-01 17:21:48,520 [INFO] root: Sampling mode of the dataloader was set to user_defined.
# 2025-10-01 17:21:48,520 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Serial augmentation enabled = False
# 2025-10-01 17:21:48,520 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Pseudo sharding enabled = False
# 2025-10-01 17:21:48,520 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Max Image Dimensions (all sources): [0, 0]
# 2025-10-01 17:21:48,520 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: number of cpus: 16, io threads: 32, compute threads: 16, buffered batches: 4
# 2025-10-01 17:21:48,521 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: total dataset size 4500, number of sources: 3, batch size per gpu: 4, steps: 1125
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# 2025-10-01 17:21:48,549 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x730741d4c4e0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x730741d4c4e0>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 17:21:48,579 [WARNING] tensorflow: Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x730741d4c4e0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x730741d4c4e0>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 17:21:48,598 [INFO] iva.detectnet_v2.dataloader.default_dataloader: Bounding box coordinates were detected in the input specification! Bboxes will be automatically converted to polygon coordinates.
# 2025-10-01 17:21:48,779 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: shuffle: False - shard 0 of 1
# WARNING:tensorflow:Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x730741d4c438>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x730741d4c438>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 17:21:48,795 [WARNING] tensorflow: Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x730741d4c438>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x730741d4c438>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 17:21:48,814 [INFO] iva.detectnet_v2.dataloader.default_dataloader: Bounding box coordinates were detected in the input specification! Bboxes will be automatically converted to polygon coordinates.
# 2025-10-01 17:21:48,989 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: shuffle: False - shard 0 of 1
# WARNING:tensorflow:Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x730741d4c630>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x730741d4c630>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 17:21:49,002 [WARNING] tensorflow: Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x730741d4c630>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x730741d4c630>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 17:21:49,022 [INFO] iva.detectnet_v2.dataloader.default_dataloader: Bounding box coordinates were detected in the input specification! Bboxes will be automatically converted to polygon coordinates.
# 2025-10-01 17:21:49,197 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: shuffle: False - shard 0 of 1
# 2025-10-01 17:21:49,204 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: sampling 3 datasets with weights:
# 2025-10-01 17:21:49,204 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: source: 0 weight: 0.400000
# 2025-10-01 17:21:49,204 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: source: 1 weight: 0.400000
# 2025-10-01 17:21:49,204 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: source: 2 weight: 0.200000
# WARNING:tensorflow:Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7306f4271908>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7306f4271908>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 17:21:49,226 [WARNING] tensorflow: Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7306f4271908>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7306f4271908>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2025-10-01 17:21:49,429 [INFO] iva.detectnet_v2.evaluation.build_evaluator: Found 4500 samples in validation set
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 3, 352, 640)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 64, 176, 320) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 64, 176, 320) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 176, 320) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_1 (Conv2D)        (None, 64, 88, 160)  36928       activation_1[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_1 (BatchNormalizati (None, 64, 88, 160)  256         block_1a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1a_relu_1 (Activation)    (None, 64, 88, 160)  0           block_1a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_2 (Conv2D)        (None, 64, 88, 160)  36928       block_1a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_shortcut (Conv2D) (None, 64, 88, 160)  4160        activation_1[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_2 (BatchNormalizati (None, 64, 88, 160)  256         block_1a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_shortcut (BatchNorm (None, 64, 88, 160)  256         block_1a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 88, 160)  0           block_1a_bn_2[0][0]
#                                                                  block_1a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_1a_relu (Activation)      (None, 64, 88, 160)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_1 (Conv2D)        (None, 64, 88, 160)  36928       block_1a_relu[0][0]
# __________________________________________________________________________________________________
# block_1b_bn_1 (BatchNormalizati (None, 64, 88, 160)  256         block_1b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1b_relu_1 (Activation)    (None, 64, 88, 160)  0           block_1b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_2 (Conv2D)        (None, 64, 88, 160)  36928       block_1b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_shortcut (Conv2D) (None, 64, 88, 160)  4160        block_1a_relu[0][0]
# __________________________________________________________________________________________________
# block_1b_bn_2 (BatchNormalizati (None, 64, 88, 160)  256         block_1b_conv_2[0][0]
# __________________________________________________________________________________________________
# block_1b_bn_shortcut (BatchNorm (None, 64, 88, 160)  256         block_1b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 88, 160)  0           block_1b_bn_2[0][0]
#                                                                  block_1b_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_1b_relu (Activation)      (None, 64, 88, 160)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_1 (Conv2D)        (None, 128, 44, 80)  73856       block_1b_relu[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_1 (BatchNormalizati (None, 128, 44, 80)  512         block_2a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2a_relu_1 (Activation)    (None, 128, 44, 80)  0           block_2a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_2 (Conv2D)        (None, 128, 44, 80)  147584      block_2a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_shortcut (Conv2D) (None, 128, 44, 80)  8320        block_1b_relu[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_2 (BatchNormalizati (None, 128, 44, 80)  512         block_2a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_shortcut (BatchNorm (None, 128, 44, 80)  512         block_2a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128, 44, 80)  0           block_2a_bn_2[0][0]
#                                                                  block_2a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2a_relu (Activation)      (None, 128, 44, 80)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_1 (Conv2D)        (None, 128, 44, 80)  147584      block_2a_relu[0][0]
# __________________________________________________________________________________________________
# block_2b_bn_1 (BatchNormalizati (None, 128, 44, 80)  512         block_2b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2b_relu_1 (Activation)    (None, 128, 44, 80)  0           block_2b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_2 (Conv2D)        (None, 128, 44, 80)  147584      block_2b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_shortcut (Conv2D) (None, 128, 44, 80)  16512       block_2a_relu[0][0]
# __________________________________________________________________________________________________
# block_2b_bn_2 (BatchNormalizati (None, 128, 44, 80)  512         block_2b_conv_2[0][0]
# __________________________________________________________________________________________________
# block_2b_bn_shortcut (BatchNorm (None, 128, 44, 80)  512         block_2b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 128, 44, 80)  0           block_2b_bn_2[0][0]
#                                                                  block_2b_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2b_relu (Activation)      (None, 128, 44, 80)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_1 (Conv2D)        (None, 256, 22, 40)  295168      block_2b_relu[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_1 (BatchNormalizati (None, 256, 22, 40)  1024        block_3a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3a_relu_1 (Activation)    (None, 256, 22, 40)  0           block_3a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_2 (Conv2D)        (None, 256, 22, 40)  590080      block_3a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_shortcut (Conv2D) (None, 256, 22, 40)  33024       block_2b_relu[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_2 (BatchNormalizati (None, 256, 22, 40)  1024        block_3a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_shortcut (BatchNorm (None, 256, 22, 40)  1024        block_3a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 256, 22, 40)  0           block_3a_bn_2[0][0]
#                                                                  block_3a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3a_relu (Activation)      (None, 256, 22, 40)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_1 (Conv2D)        (None, 256, 22, 40)  590080      block_3a_relu[0][0]
# __________________________________________________________________________________________________
# block_3b_bn_1 (BatchNormalizati (None, 256, 22, 40)  1024        block_3b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3b_relu_1 (Activation)    (None, 256, 22, 40)  0           block_3b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_2 (Conv2D)        (None, 256, 22, 40)  590080      block_3b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_shortcut (Conv2D) (None, 256, 22, 40)  65792       block_3a_relu[0][0]
# __________________________________________________________________________________________________
# block_3b_bn_2 (BatchNormalizati (None, 256, 22, 40)  1024        block_3b_conv_2[0][0]
# __________________________________________________________________________________________________
# block_3b_bn_shortcut (BatchNorm (None, 256, 22, 40)  1024        block_3b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 256, 22, 40)  0           block_3b_bn_2[0][0]
#                                                                  block_3b_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3b_relu (Activation)      (None, 256, 22, 40)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_1 (Conv2D)        (None, 512, 22, 40)  1180160     block_3b_relu[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_1 (BatchNormalizati (None, 512, 22, 40)  2048        block_4a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4a_relu_1 (Activation)    (None, 512, 22, 40)  0           block_4a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_2 (Conv2D)        (None, 512, 22, 40)  2359808     block_4a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_shortcut (Conv2D) (None, 512, 22, 40)  131584      block_3b_relu[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_2 (BatchNormalizati (None, 512, 22, 40)  2048        block_4a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_shortcut (BatchNorm (None, 512, 22, 40)  2048        block_4a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 512, 22, 40)  0           block_4a_bn_2[0][0]
#                                                                  block_4a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_4a_relu (Activation)      (None, 512, 22, 40)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_1 (Conv2D)        (None, 512, 22, 40)  2359808     block_4a_relu[0][0]
# __________________________________________________________________________________________________
# block_4b_bn_1 (BatchNormalizati (None, 512, 22, 40)  2048        block_4b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4b_relu_1 (Activation)    (None, 512, 22, 40)  0           block_4b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_2 (Conv2D)        (None, 512, 22, 40)  2359808     block_4b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_shortcut (Conv2D) (None, 512, 22, 40)  262656      block_4a_relu[0][0]
# __________________________________________________________________________________________________
# block_4b_bn_2 (BatchNormalizati (None, 512, 22, 40)  2048        block_4b_conv_2[0][0]
# __________________________________________________________________________________________________
# block_4b_bn_shortcut (BatchNorm (None, 512, 22, 40)  2048        block_4b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 512, 22, 40)  0           block_4b_bn_2[0][0]
#                                                                  block_4b_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_4b_relu (Activation)      (None, 512, 22, 40)  0           add_8[0][0]
# __________________________________________________________________________________________________
# output_bbox (Conv2D)            (None, 4, 22, 40)    2052        block_4b_relu[0][0]
# __________________________________________________________________________________________________
# output_cov (Conv2D)             (None, 1, 22, 40)    513         block_4b_relu[0][0]              INFO:tensorflow:Graph was finalized.
# 2025-10-01 17:21:50,272 [INFO] tensorflow: Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# 2025-10-01 17:21:50,852 [INFO] tensorflow: Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 2025-10-01 17:21:51,556 [INFO] tensorflow: Done running local_init_op.
# 2025-10-01 17:21:52,692 [INFO] iva.detectnet_v2.evaluation.evaluation: step 0 / 1125, 0.00s/step
# 2025-10-01 17:21:56,779 [INFO] iva.detectnet_v2.evaluation.evaluation: step 10 / 1125, 0.41s/step
# 2025-10-01 17:21:57,358 [INFO] iva.detectnet_v2.evaluation.evaluation: step 20 / 1125, 0.06s/step
# 2025-10-01 17:21:57,893 [INFO] iva.detectnet_v2.evaluation.evaluation: step 30 / 1125, 0.05s/step
# 2025-10-01 17:21:58,458 [INFO] iva.detectnet_v2.evaluation.evaluation: step 40 / 1125, 0.06s/step
# 2025-10-01 17:21:59,004 [INFO] iva.detectnet_v2.evaluation.evaluation: step 50 / 1125, 0.05s/step
# 2025-10-01 17:21:59,575 [INFO] iva.detectnet_v2.evaluation.evaluation: step 60 / 1125, 0.06s/step
# 2025-10-01 17:22:00,157 [INFO] iva.detectnet_v2.evaluation.evaluation: step 70 / 1125, 0.06s/step
# 2025-10-01 17:22:00,720 [INFO] iva.detectnet_v2.evaluation.evaluation: step 80 / 1125, 0.06s/step
# 2025-10-01 17:22:01,277 [INFO] iva.detectnet_v2.evaluation.evaluation: step 90 / 1125, 0.06s/step
# 2025-10-01 17:22:01,850 [INFO] iva.detectnet_v2.evaluation.evaluation: step 100 / 1125, 0.06s/step
# 2025-10-01 17:22:02,415 [INFO] iva.detectnet_v2.evaluation.evaluation: step 110 / 1125, 0.06s/step
# 2025-10-01 17:22:03,015 [INFO] iva.detectnet_v2.evaluation.evaluation: step 120 / 1125, 0.06s/step
# 2025-10-01 17:22:03,630 [INFO] iva.detectnet_v2.evaluation.evaluation: step 130 / 1125, 0.06s/step
# 2025-10-01 17:22:04,259 [INFO] iva.detectnet_v2.evaluation.evaluation: step 140 / 1125, 0.06s/step
# 2025-10-01 17:22:04,874 [INFO] iva.detectnet_v2.evaluation.evaluation: step 150 / 1125, 0.06s/step
# 2025-10-01 17:22:05,503 [INFO] iva.detectnet_v2.evaluation.evaluation: step 160 / 1125, 0.06s/step
# 2025-10-01 17:22:06,074 [INFO] iva.detectnet_v2.evaluation.evaluation: step 170 / 1125, 0.06s/step
# 2025-10-01 17:22:06,656 [INFO] iva.detectnet_v2.evaluation.evaluation: step 180 / 1125, 0.06s/step
# 2025-10-01 17:22:07,235 [INFO] iva.detectnet_v2.evaluation.evaluation: step 190 / 1125, 0.06s/step
# 2025-10-01 17:22:07,782 [INFO] iva.detectnet_v2.evaluation.evaluation: step 200 / 1125, 0.05s/step
# 2025-10-01 17:22:08,333 [INFO] iva.detectnet_v2.evaluation.evaluation: step 210 / 1125, 0.06s/step
# 2025-10-01 17:22:08,909 [INFO] iva.detectnet_v2.evaluation.evaluation: step 220 / 1125, 0.06s/step
# 2025-10-01 17:22:09,479 [INFO] iva.detectnet_v2.evaluation.evaluation: step 230 / 1125, 0.06s/step
# 2025-10-01 17:22:10,094 [INFO] iva.detectnet_v2.evaluation.evaluation: step 240 / 1125, 0.06s/step
# 2025-10-01 17:22:10,672 [INFO] iva.detectnet_v2.evaluation.evaluation: step 250 / 1125, 0.06s/step
# 2025-10-01 17:22:11,242 [INFO] iva.detectnet_v2.evaluation.evaluation: step 260 / 1125, 0.06s/step
# 2025-10-01 17:22:11,805 [INFO] iva.detectnet_v2.evaluation.evaluation: step 270 / 1125, 0.06s/step
# 2025-10-01 17:22:12,381 [INFO] iva.detectnet_v2.evaluation.evaluation: step 280 / 1125, 0.06s/step
# 2025-10-01 17:22:12,932 [INFO] iva.detectnet_v2.evaluation.evaluation: step 290 / 1125, 0.06s/step
# 2025-10-01 17:22:13,497 [INFO] iva.detectnet_v2.evaluation.evaluation: step 300 / 1125, 0.06s/step
# 2025-10-01 17:22:14,068 [INFO] iva.detectnet_v2.evaluation.evaluation: step 310 / 1125, 0.06s/step
# 2025-10-01 17:22:14,730 [INFO] iva.detectnet_v2.evaluation.evaluation: step 320 / 1125, 0.07s/step
# 2025-10-01 17:22:15,296 [INFO] iva.detectnet_v2.evaluation.evaluation: step 330 / 1125, 0.06s/step
# 2025-10-01 17:22:15,872 [INFO] iva.detectnet_v2.evaluation.evaluation: step 340 / 1125, 0.06s/step
# 2025-10-01 17:22:16,446 [INFO] iva.detectnet_v2.evaluation.evaluation: step 350 / 1125, 0.06s/step
# 2025-10-01 17:22:17,020 [INFO] iva.detectnet_v2.evaluation.evaluation: step 360 / 1125, 0.06s/step
# 2025-10-01 17:22:17,586 [INFO] iva.detectnet_v2.evaluation.evaluation: step 370 / 1125, 0.06s/step
# 2025-10-01 17:22:18,124 [INFO] iva.detectnet_v2.evaluation.evaluation: step 380 / 1125, 0.05s/step
# 2025-10-01 17:22:18,707 [INFO] iva.detectnet_v2.evaluation.evaluation: step 390 / 1125, 0.06s/step
# 2025-10-01 17:22:19,267 [INFO] iva.detectnet_v2.evaluation.evaluation: step 400 / 1125, 0.06s/step
# 2025-10-01 17:22:19,825 [INFO] iva.detectnet_v2.evaluation.evaluation: step 410 / 1125, 0.06s/step
# 2025-10-01 17:22:20,375 [INFO] iva.detectnet_v2.evaluation.evaluation: step 420 / 1125, 0.05s/step
# 2025-10-01 17:22:20,948 [INFO] iva.detectnet_v2.evaluation.evaluation: step 430 / 1125, 0.06s/step
# 2025-10-01 17:22:21,538 [INFO] iva.detectnet_v2.evaluation.evaluation: step 440 / 1125, 0.06s/step
# 2025-10-01 17:22:22,067 [INFO] iva.detectnet_v2.evaluation.evaluation: step 450 / 1125, 0.05s/step
# 2025-10-01 17:22:22,639 [INFO] iva.detectnet_v2.evaluation.evaluation: step 460 / 1125, 0.06s/step
# 2025-10-01 17:22:23,187 [INFO] iva.detectnet_v2.evaluation.evaluation: step 470 / 1125, 0.05s/step
# 2025-10-01 17:22:23,729 [INFO] iva.detectnet_v2.evaluation.evaluation: step 480 / 1125, 0.05s/step
# 2025-10-01 17:22:24,313 [INFO] iva.detectnet_v2.evaluation.evaluation: step 490 / 1125, 0.06s/step
# 2025-10-01 17:22:24,898 [INFO] iva.detectnet_v2.evaluation.evaluation: step 500 / 1125, 0.06s/step
# 2025-10-01 17:22:25,456 [INFO] iva.detectnet_v2.evaluation.evaluation: step 510 / 1125, 0.06s/step
# 2025-10-01 17:22:25,987 [INFO] iva.detectnet_v2.evaluation.evaluation: step 520 / 1125, 0.05s/step
# 2025-10-01 17:22:26,538 [INFO] iva.detectnet_v2.evaluation.evaluation: step 530 / 1125, 0.06s/step
# 2025-10-01 17:22:27,103 [INFO] iva.detectnet_v2.evaluation.evaluation: step 540 / 1125, 0.06s/step
# 2025-10-01 17:22:27,671 [INFO] iva.detectnet_v2.evaluation.evaluation: step 550 / 1125, 0.06s/step
# 2025-10-01 17:22:28,233 [INFO] iva.detectnet_v2.evaluation.evaluation: step 560 / 1125, 0.06s/step
# 2025-10-01 17:22:28,784 [INFO] iva.detectnet_v2.evaluation.evaluation: step 570 / 1125, 0.06s/step
# 2025-10-01 17:22:29,338 [INFO] iva.detectnet_v2.evaluation.evaluation: step 580 / 1125, 0.06s/step
# 2025-10-01 17:22:29,894 [INFO] iva.detectnet_v2.evaluation.evaluation: step 590 / 1125, 0.06s/step
# 2025-10-01 17:22:30,444 [INFO] iva.detectnet_v2.evaluation.evaluation: step 600 / 1125, 0.05s/step
# 2025-10-01 17:22:31,006 [INFO] iva.detectnet_v2.evaluation.evaluation: step 610 / 1125, 0.06s/step
# 2025-10-01 17:22:31,575 [INFO] iva.detectnet_v2.evaluation.evaluation: step 620 / 1125, 0.06s/step
# 2025-10-01 17:22:32,132 [INFO] iva.detectnet_v2.evaluation.evaluation: step 630 / 1125, 0.06s/step
# 2025-10-01 17:22:32,698 [INFO] iva.detectnet_v2.evaluation.evaluation: step 640 / 1125, 0.06s/step
# 2025-10-01 17:22:33,239 [INFO] iva.detectnet_v2.evaluation.evaluation: step 650 / 1125, 0.05s/step
# 2025-10-01 17:22:33,778 [INFO] iva.detectnet_v2.evaluation.evaluation: step 660 / 1125, 0.05s/step
# 2025-10-01 17:22:34,398 [INFO] iva.detectnet_v2.evaluation.evaluation: step 670 / 1125, 0.06s/step
# 2025-10-01 17:22:34,972 [INFO] iva.detectnet_v2.evaluation.evaluation: step 680 / 1125, 0.06s/step
# 2025-10-01 17:22:35,509 [INFO] iva.detectnet_v2.evaluation.evaluation: step 690 / 1125, 0.05s/step
# 2025-10-01 17:22:36,068 [INFO] iva.detectnet_v2.evaluation.evaluation: step 700 / 1125, 0.06s/step
# 2025-10-01 17:22:36,629 [INFO] iva.detectnet_v2.evaluation.evaluation: step 710 / 1125, 0.06s/step
# 2025-10-01 17:22:37,203 [INFO] iva.detectnet_v2.evaluation.evaluation: step 720 / 1125, 0.06s/step
# 2025-10-01 17:22:37,757 [INFO] iva.detectnet_v2.evaluation.evaluation: step 730 / 1125, 0.06s/step
# 2025-10-01 17:22:38,332 [INFO] iva.detectnet_v2.evaluation.evaluation: step 740 / 1125, 0.06s/step
# 2025-10-01 17:22:38,892 [INFO] iva.detectnet_v2.evaluation.evaluation: step 750 / 1125, 0.06s/step
# 2025-10-01 17:22:39,491 [INFO] iva.detectnet_v2.evaluation.evaluation: step 760 / 1125, 0.06s/step
# 2025-10-01 17:22:40,089 [INFO] iva.detectnet_v2.evaluation.evaluation: step 770 / 1125, 0.06s/step
# 2025-10-01 17:22:40,672 [INFO] iva.detectnet_v2.evaluation.evaluation: step 780 / 1125, 0.06s/step
# 2025-10-01 17:22:41,231 [INFO] iva.detectnet_v2.evaluation.evaluation: step 790 / 1125, 0.06s/step
# 2025-10-01 17:22:41,805 [INFO] iva.detectnet_v2.evaluation.evaluation: step 800 / 1125, 0.06s/step
# 2025-10-01 17:22:42,391 [INFO] iva.detectnet_v2.evaluation.evaluation: step 810 / 1125, 0.06s/step
# 2025-10-01 17:22:42,975 [INFO] iva.detectnet_v2.evaluation.evaluation: step 820 / 1125, 0.06s/step
# 2025-10-01 17:22:43,567 [INFO] iva.detectnet_v2.evaluation.evaluation: step 830 / 1125, 0.06s/step
# 2025-10-01 17:22:44,167 [INFO] iva.detectnet_v2.evaluation.evaluation: step 840 / 1125, 0.06s/step
# 2025-10-01 17:22:44,770 [INFO] iva.detectnet_v2.evaluation.evaluation: step 850 / 1125, 0.06s/step
# 2025-10-01 17:22:45,374 [INFO] iva.detectnet_v2.evaluation.evaluation: step 860 / 1125, 0.06s/step
# 2025-10-01 17:22:45,971 [INFO] iva.detectnet_v2.evaluation.evaluation: step 870 / 1125, 0.06s/step
# 2025-10-01 17:22:46,553 [INFO] iva.detectnet_v2.evaluation.evaluation: step 880 / 1125, 0.06s/step
# 2025-10-01 17:22:47,154 [INFO] iva.detectnet_v2.evaluation.evaluation: step 890 / 1125, 0.06s/step
# 2025-10-01 17:22:47,725 [INFO] iva.detectnet_v2.evaluation.evaluation: step 900 / 1125, 0.06s/step
# 2025-10-01 17:22:48,374 [INFO] iva.detectnet_v2.evaluation.evaluation: step 910 / 1125, 0.06s/step
# 2025-10-01 17:22:48,984 [INFO] iva.detectnet_v2.evaluation.evaluation: step 920 / 1125, 0.06s/step
# 2025-10-01 17:22:49,594 [INFO] iva.detectnet_v2.evaluation.evaluation: step 930 / 1125, 0.06s/step
# 2025-10-01 17:22:50,204 [INFO] iva.detectnet_v2.evaluation.evaluation: step 940 / 1125, 0.06s/step
# 2025-10-01 17:22:50,822 [INFO] iva.detectnet_v2.evaluation.evaluation: step 950 / 1125, 0.06s/step
# 2025-10-01 17:22:51,439 [INFO] iva.detectnet_v2.evaluation.evaluation: step 960 / 1125, 0.06s/step
# 2025-10-01 17:22:52,072 [INFO] iva.detectnet_v2.evaluation.evaluation: step 970 / 1125, 0.06s/step
# 2025-10-01 17:22:52,677 [INFO] iva.detectnet_v2.evaluation.evaluation: step 980 / 1125, 0.06s/step
# 2025-10-01 17:22:53,264 [INFO] iva.detectnet_v2.evaluation.evaluation: step 990 / 1125, 0.06s/step
# 2025-10-01 17:22:53,833 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1000 / 1125, 0.06s/step
# 2025-10-01 17:22:54,499 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1010 / 1125, 0.07s/step
# 2025-10-01 17:22:55,086 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1020 / 1125, 0.06s/step
# 2025-10-01 17:22:55,665 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1030 / 1125, 0.06s/step
# 2025-10-01 17:22:56,227 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1040 / 1125, 0.06s/step
# 2025-10-01 17:22:56,815 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1050 / 1125, 0.06s/step
# 2025-10-01 17:22:57,520 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1060 / 1125, 0.07s/step
# 2025-10-01 17:22:58,157 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1070 / 1125, 0.06s/step
# 2025-10-01 17:22:58,802 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1080 / 1125, 0.06s/step
# 2025-10-01 17:22:59,604 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1090 / 1125, 0.08s/step
# 2025-10-01 17:23:00,262 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1100 / 1125, 0.07s/step
# 2025-10-01 17:23:00,869 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1110 / 1125, 0.06s/step
# 2025-10-01 17:23:01,508 [INFO] iva.detectnet_v2.evaluation.evaluation: step 1120 / 1125, 0.06s/step
#
# ==================================================================================================
# Total params: 11,550,853
# Trainable params: 11,539,205
# Non-trainable params: 11,648
# __________________________________________________________________________________________________
#
#   0%|          | 0/50357 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 1/1.:   0%|          | 0/50357 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 1/1.:   2%|▏         | 1213/50357 [00:00<00:04, 12117.36it/s]
# Matching predictions to ground truth, class 1/1.:   5%|▍         | 2427/50357 [00:00<00:03, 12127.52it/s]
# Matching predictions to ground truth, class 1/1.:   7%|▋         | 3524/50357 [00:00<00:03, 11741.17it/s]
# Matching predictions to ground truth, class 1/1.:  10%|▉         | 4810/50357 [00:00<00:03, 12020.29it/s]
# Matching predictions to ground truth, class 1/1.:  13%|█▎        | 6410/50357 [00:00<00:03, 12815.51it/s]
# Matching predictions to ground truth, class 1/1.:  16%|█▌        | 8003/50357 [00:00<00:03, 13333.76it/s]
# Matching predictions to ground truth, class 1/1.:  19%|█▉        | 9539/50357 [00:00<00:02, 13622.41it/s]
# Matching predictions to ground truth, class 1/1.:  22%|██▏       | 10885/50357 [00:00<00:02, 13485.31it/s]
# Matching predictions to ground truth, class 1/1.:  24%|██▍       | 12263/50357 [00:00<00:02, 13517.75it/s]
# Matching predictions to ground truth, class 1/1.:  27%|██▋       | 13601/50357 [00:01<00:02, 13480.98it/s]
# Matching predictions to ground truth, class 1/1.:  30%|██▉       | 14932/50357 [00:01<00:02, 13444.35it/s]
# Matching predictions to ground truth, class 1/1.:  32%|███▏      | 16256/50357 [00:01<00:02, 13080.12it/s]
# Matching predictions to ground truth, class 1/1.:  35%|███▍      | 17484/50357 [00:01<00:02, 12649.09it/s]
# Matching predictions to ground truth, class 1/1.:  37%|███▋      | 18704/50357 [00:01<00:02, 12618.54it/s]
# Matching predictions to ground truth, class 1/1.:  40%|████      | 20170/50357 [00:01<00:02, 12747.38it/s]
# Matching predictions to ground truth, class 1/1.:  43%|████▎     | 21758/50357 [00:01<00:02, 12933.57it/s]
# Matching predictions to ground truth, class 1/1.:  46%|████▋     | 23407/50357 [00:01<00:02, 13133.04it/s]
# Matching predictions to ground truth, class 1/1.:  50%|████▉     | 24973/50357 [00:01<00:01, 13266.95it/s]
# Matching predictions to ground truth, class 1/1.:  53%|█████▎    | 26586/50357 [00:01<00:01, 13411.11it/s]
# Matching predictions to ground truth, class 1/1.:  56%|█████▌    | 28104/50357 [00:02<00:01, 13416.93it/s]
# Matching predictions to ground truth, class 1/1.:  59%|█████▉    | 29586/50357 [00:02<00:01, 13479.18it/s]
# Matching predictions to ground truth, class 1/1.:  62%|██████▏   | 31057/50357 [00:02<00:01, 13445.31it/s]
# Matching predictions to ground truth, class 1/1.:  64%|██████▍   | 32471/50357 [00:02<00:01, 13006.76it/s]
# Matching predictions to ground truth, class 1/1.:  67%|██████▋   | 33688/50357 [00:02<00:01, 12768.05it/s]
# Matching predictions to ground truth, class 1/1.:  69%|██████▉   | 34797/50357 [00:02<00:01, 12635.18it/s]
# Matching predictions to ground truth, class 1/1.:  71%|███████   | 35862/50357 [00:02<00:01, 12482.82it/s]
# Matching predictions to ground truth, class 1/1.:  73%|███████▎  | 36876/50357 [00:02<00:01, 12324.62it/s]
# Matching predictions to ground truth, class 1/1.:  75%|███████▌  | 37841/50357 [00:03<00:01, 12195.23it/s]
# Matching predictions to ground truth, class 1/1.:  77%|███████▋  | 38778/50357 [00:03<00:00, 12037.98it/s]
# Matching predictions to ground truth, class 1/1.:  79%|███████▉  | 39672/50357 [00:03<00:00, 11874.56it/s]
# Matching predictions to ground truth, class 1/1.:  81%|████████  | 40659/50357 [00:03<00:00, 11816.03it/s]
# Matching predictions to ground truth, class 1/1.:  83%|████████▎ | 41808/50357 [00:03<00:00, 11806.79it/s]
# Matching predictions to ground truth, class 1/1.:  86%|████████▌ | 43098/50357 [00:03<00:00, 11836.70it/s]
# Matching predictions to ground truth, class 1/1.:  88%|████████▊ | 44284/50357 [00:03<00:00, 11837.20it/s]
# Matching predictions to ground truth, class 1/1.:  91%|█████████ | 45804/50357 [00:03<00:00, 11924.70it/s]
# Matching predictions to ground truth, class 1/1.:  93%|█████████▎| 47033/50357 [00:03<00:00, 11933.94it/s]
# Matching predictions to ground truth, class 1/1.:  97%|█████████▋| 48617/50357 [00:04<00:00, 12030.45it/s]
# Matching predictions to ground truth, class 1/1.: 100%|█████████▉| 50123/50357 [00:04<00:00, 12103.56it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 50357/50357 [00:04<00:00, 12118.49it/s]WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# 2025-10-01 17:23:07,296 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# 2025-10-01 17:23:07,297 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
#
#
# Validation cost: 0.004159
# Mean average_precision (in %): 35.6643
#
# class name      average precision (in %)
# ------------  --------------------------
# palletjack                       35.6643
#
# Median Inference Time: 0.010899
# 2025-10-01 17:23:07,375 [INFO] __main__: Evaluation complete.
# Time taken to run __main__:main: 0:01:25.397516.
# Telemetry data couldn't be sent, but the command ran successfully.
# [WARNING]: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)>
# Execution status: PASS
# 2025-10-01 17:21:34.785025: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %% [markdown]
# ## 7. Visualize Model Performance on Real World Data <a class="anchor" id="head-7"></a>
#
# * Lets visualize the model predictions on a few sample real world images next
# * We will use palletjack images in a warehouse from the `LOCO` dataset to understand if the model is capable of performing real world detections
# * Additional images can be placed under the `loco_palletjacks` folder of this project. The input folder is specified with the `-i` flag in the command below

# %%
# !docker run --rm --gpus all -v E:/synthetic_data_generation_training_workflow:/workspace/tao-experiments nvcr.io/nvidia/tao/tao-toolkit:4.0.0-tf1.15.5 \
  detectnet_v2 inference \
  -e /workspace/tao-experiments/local/training/tao/specs/inference/new_inference_specs.txt \
  -o /workspace/tao-experiments/local/training/tao/detectnet_v2/resnet18_palletjack/5k_model_synthetic \
  -i /workspace/tao-experiments/images/sample_synthetic \
  -k nvidia_tlt
# Out:
# ==============================
# === TAO Toolkit TensorFlow ===
# ==============================
#
# NVIDIA Release 4.0.0-TensorFlow (build )
# TAO Toolkit Version 4.0.0
#
# Various files include modifications (c) NVIDIA CORPORATION & AFFILIATES.  All rights reserved.
#
# This container image and its contents are governed by the TAO Toolkit End User License Agreement.
# By pulling and using the container, you accept the terms and conditions of this license:
# https://developer.nvidia.com/tao-toolkit-software-license-agreement
#
# NOTE: The SHMEM allocation limit is set to the default of 64MB.  This may be
#    insufficient for TAO Toolkit.  NVIDIA recommends the use of the following flags:
#    docker run --gpus all --ipc=host --ulimit memlock=-1 --ulimit stack=67108864 ...
#
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# INFO: Merging specification from /workspace/tao-experiments/local/training/tao/specs/inference/new_inference_specs.txt
# INFO: Creating output inference directory
# INFO: Overlain images will be saved in the output path.
# INFO: Constructing inferencer
# INFO: Loading model from /workspace/tao-experiments/local/training/tao/detectnet_v2/resnet18_palletjack/weights/model.tlt:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:245: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:245: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# INFO: Initialized model
# INFO: Commencing inference
#
#   0%|          | 0/1 [00:00<?, ?it/s]_________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3, 544, 960)       0
# _________________________________________________________________
# model_1 (Model)              multiple                  11550853
# =================================================================
# Total params: 11,550,853
# Trainable params: 11,539,205
# Non-trainable params: 11,648
# _________________________________________________________________
#
# 100%|██████████| 1/1 [00:12<00:00, 12.81s/it]
# INFO: Inference complete
# Telemetry data couldn't be sent, but the command ran successfully.
# [WARNING]: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)>
# Execution status: PASS
# 2025-10-01 20:12:45.755403: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
from IPython.display import Image, display
import os

annotated_dir = "E:/synthetic_data_generation_training_workflow/local/training/tao/detectnet_v2/resnet18_palletjack/5k_model_synthetic/images_annotated"

# List all annotated image files
image_names = os.listdir(annotated_dir)
print("Annotated images:", image_names[:10])  # Show the first 10 filenames for sanity check

# Visualize the first few annotated images (change slice as needed)
sample_images = image_names[:5]
images = [Image(filename=os.path.join(annotated_dir, img)) for img in sample_images]
display(*images)
# Out:
# Annotated images: ['138.png', '1545.png', '203.png', '21.png', '215.png', '220.png', '378.png', '411.png', '444.png', '512.png']
